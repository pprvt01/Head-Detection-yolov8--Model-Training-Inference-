# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11
# Out:
# /content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=50 imgsz=640  batch=30 lr0=0.01
# Out:
# /content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11
# ...
# 100% 21.5M/21.5M [00:00<00:00, 110MB/s]
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11/runs/detect/train3/weights/best.pt")
results = model("/content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11/1.jpeg", save=True)

results[0].show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model = YOLO("/content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11/runs/detect/train3/weights/best.pt")
results = model("/content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11/2.jpeg", save=True)

results[0].show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import cv2

model= YOLO("/content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11/runs/detect/train3/weights/best.pt")
inmg_path="/content/drive/MyDrive/Head Detection /Head Detection.v1i.yolov11/2.jpeg"
